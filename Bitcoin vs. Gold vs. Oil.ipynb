# %%
from sources import quandl
from utils import merge_dfs_column, to_datetime
import numpy as np
from viz import plot_scatter_df_series
import plotly.offline as py

# %%
opec_data = quandl.fetch_data_with_cache('OPEC/ORB')
gold_data = quandl.fetch_data_with_cache('LBMA/GOLD')
bitcoin_data = quandl.fetch_data_with_cache('BCHARTS/BITSTAMPUSD')

# %%
gold_data['Value'] = gold_data['USD (AM)']
bitcoin_data['Value'] = bitcoin_data['Weighted Price']

# %%
oil_btc_gold = merge_dfs_column({'btc':bitcoin_data, 'oil':opec_data, 'gold':gold_data}, 'Value')

# %%
oil_btc_gold.replace(0, np.nan, inplace=True)

# %%
oil_btc_gold = oil_btc_gold['2011-10-01':]

# %%
fig = plot_scatter_df_series(oil_btc_gold, 'Bitcoin vs. Oil vs. Gold', y_axis_label='USD', scale='log')

# %%
py.iplot(fig)
# Out:
# <div>
#
#
#             <div id="5c327386-afaa-4130-8fce-dc88e6c5f1fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5c327386-afaa-4130-8fce-dc88e6c5f1fe")) {
#                     Plotly.newPlot(
#                         '5c327386-afaa-4130-8fce-dc88e6c5f1fe',
# ...
